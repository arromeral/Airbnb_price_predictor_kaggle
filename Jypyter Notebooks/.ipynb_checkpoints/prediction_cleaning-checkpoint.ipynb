# %% [markdown]
# # Este Notebook es el utilizado para replicar las transformaciones hechas para el conjunto train ahora con el dataset completo
#
# ## Salvo mención específica se han seguido las mismas transformaciones que en el Jupyter Notebook llamado train_cleaning

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import euclidean_distances
from scipy.spatial.distance import cdist
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder , OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import seaborn as sns
from sklearn.preprocessing import MultiLabelBinarizer

# %%
bnb = pd.read_csv("../data/train.csv")
bnb2 = pd.read_csv("../data/test.csv")

# %%
bnb3 = pd.concat([bnb,bnb2])

# %%
pd.set_option('display.max_columns', None)
bnb3.head()
# Out:
#          id  log_price property_type        room_type  \
# 0  15148661   4.499810     Apartment  Entire home/apt
# 1   1227528   3.970292     Apartment     Private room
# 2  15692740   4.787492     Apartment  Entire home/apt
# 3  19115685   4.700480     Apartment  Entire home/apt
# 4   2554110   5.192957     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
# 1  {Internet,"Wireless Internet","Air conditionin...             2        1.0
# 2  {"Wireless Internet","Air conditioning","Wheel...             4        1.0
# 3  {Internet,"Wireless Internet","Air conditionin...             3        NaN
# 4  {TV,"Wireless Internet","Air conditioning",Kit...             3        1.0
#
#    bed_type cancellation_policy  cleaning_fee city  \
# 0  Real Bed            flexible          True  NYC
# 1     Futon              strict          True  NYC
# 2  Real Bed            moderate          True  NYC
# 3  Real Bed            moderate         False  NYC
# 4  Real Bed              strict          True  NYC
#
#                                          description first_review  \
# 0  A great spacious apartment in an awesome and c...   2016-07-25
# 1  Newly Renovated Two Bedroom Apartment in Hamil...   2016-09-01
# 2  One bedroom, one bathroom apartment, with an o...   2016-01-05
# 3  Comfy, art- and book-filled one-bedroom apartm...   2014-01-06
# 4  1br/1ba. Spacious living room with plenty of s...   2016-05-20
#
#   host_has_profile_pic host_identity_verified host_response_rate  host_since  \
# 0                    t                      t                80%  2015-11-04
# 1                    t                      t                NaN  2014-08-26
# 2                    t                      t               100%  2011-01-29
# 3                    t                      f                NaN  2011-10-26
# 4                    t                      f                NaN  2012-06-21
#
#   instant_bookable last_review   latitude  longitude  \
# 0                f  2017-09-10  40.757349 -73.921339
# 1                f  2017-01-05  40.823556 -73.954573
# 2                f  2017-09-27  40.689306 -73.955478
# 3                f  2014-01-13  40.681965 -73.965490
# 4                f  2016-05-20  40.742842 -73.957554
#
#                                                 name       neighbourhood  \
# 0  Sunny Spacious Apt in Astoria w/ back yard access             Astoria
# 1                       Manhattan Sunny Private Room    Hamilton Heights
# 2                     Sweet Apartment on Quiet Block  Bedford-Stuyvesant
# 3                Husband & Wife Art-Filled Apartment        Clinton Hill
# 4                           Luxurious 1 Bedroom Apt!    Long Island City
#
#    number_of_reviews  review_scores_rating  \
# 0                  9                  96.0
# 1                  8                 100.0
# 2                 12                 100.0
# 3                  2                  90.0
# 4                  1                  80.0
#
#                                        thumbnail_url  zipcode  bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/3e40924b-7...    11101       1.0   1.0
# 1  https://a0.muscache.com/im/pictures/2953dddd-0...    10031       1.0   1.0
# 2                                                NaN    11205       1.0   1.0
# 3  https://a0.muscache.com/im/pictures/81766960/b...  11238.0       1.0   1.0
# 4  https://a0.muscache.com/im/pictures/0ed6ee9e-6...    11101       1.0   1.0

# %%
bnb3.info(memory_usage = "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74111 entries, 0 to 14822
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               59288 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
#  14  host_identity_verified  73923 non-null  object
#  15  host_response_rate      55812 non-null  object
#  16  host_since              73923 non-null  object
#  17  instant_bookable        74111 non-null  object
#  18  last_review             58284 non-null  object
#  19  latitude                74111 non-null  float64
#  20  longitude               74111 non-null  float64
#  21  name                    74111 non-null  object
#  22  neighbourhood           67239 non-null  object
#  23  number_of_reviews       74111 non-null  int64
#  24  review_scores_rating    57389 non-null  float64
#  25  thumbnail_url           65895 non-null  object
#  26  zipcode                 73145 non-null  object
#  27  bedrooms                74020 non-null  float64
#  28  beds                    73980 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(18)
# memory usage: 173.9 MB

# %% [markdown]
# # Convierto todos los property_type que aparecen menos de 10 veces por "Other"

# %%
prop_counts = bnb3['property_type'].value_counts()
prop_counts
# Out:
# Apartment             49003
# House                 16511
# Condominium            2658
# Townhouse              1692
# Loft                   1244
# Other                   607
# Guesthouse              498
# Bed & Breakfast         462
# Bungalow                366
# Villa                   179
# Dorm                    142
# Guest suite             123
# Camper/RV                94
# Timeshare                77
# Cabin                    72
# In-law                   71
# Hostel                   70
# Boutique hotel           69
# Boat                     65
# Serviced apartment       21
# Tent                     18
# Castle                   13
# Vacation home            11
# Yurt                      9
# Hut                       8
# Treehouse                 7
# Chalet                    6
# Earth House               4
# Tipi                      3
# Cave                      2
# Train                     2
# Lighthouse                1
# Casa particular           1
# Island                    1
# Parking Space             1
# Name: property_type, dtype: int64

# %%
# Identificar tipos con recuento menor que 10
tipos_a_cambiar = prop_counts[prop_counts < 10].index

# Cambiar los valores en la columna property_type
bnb3['property_type'] = bnb3['property_type'].map(lambda x: 'Other' if x in tipos_a_cambiar else x)

# %% [markdown]
# # Relleno los valores nulos en la columna bathroom con el promedio de baños para el número de huespedes

# %%
# Calcular el promedio de baños para cada número de acomodates
average_bathrooms = bnb3.groupby('accommodates')['bathrooms'].transform('mean')

# Llenar los valores nulos en la columna 'bathrooms' con los promedios calculados
bnb3['bathrooms'] = bnb3['bathrooms'].fillna(average_bathrooms)
bnb3['bathrooms'] = bnb3['bathrooms'].round(1)

# %% [markdown]
# # Paso la columna cleaning_fee de tipo bool a int

# %%
bnb3['cleaning_fee'] = bnb3['cleaning_fee'].astype(int)

# %% [markdown]
# # Parece que no hay gran diferencia entre tener foto de perfil o estar verificado en el log_price por lo que se van a eliminar esas dos columnas

# %%
columnas_a_eliminar = ['host_has_profile_pic', 'host_identity_verified']
bnb3 = bnb3.drop(columnas_a_eliminar, axis=1)

# %% [markdown]
# # Relleno los nulos de la columna host_since por el valor de first_review cuando sea posible, y por la fecha más reciente de host_since cuando first_review sea nulo tambien

# %%
bnb3['host_since'] = bnb3['host_since'].fillna(bnb3['first_review'])

# %%
bnb3['host_since'] = bnb3['host_since'].fillna("-")

# %%
bnb3['host_since'] = bnb3['host_since'].replace('-', '2017-10-04')

# %%
bnb3 = bnb3.drop("first_review", axis=1)

# %%
bnb3['host_response_rate'] = bnb3['host_response_rate'].str.rstrip('%').astype('float')

# Rellenar los valores nulos con la media
media = bnb3['host_response_rate'].mean()
bnb3['host_response_rate'].fillna(media, inplace=True)

# %%
bnb3['host_response_rate'] = bnb3['host_response_rate'].astype(int)

# %% [markdown]
# # Cambio la columna instant_bookable a binario

# %%
bnb3['instant_bookable'] = bnb3['instant_bookable'].replace('f', 0)
bnb3['instant_bookable'] = bnb3['instant_bookable'].replace('t', 1)

# %% [markdown]
# # Elimino la columna last_review y las columnas latitude y longitude ya que posteriormente voy a tratar de cuantificar la ubicación del alojamiento mediante clusterización de neighbourhood

# %%
bnb3 = bnb3.drop("last_review", axis=1)

# %%
len(bnb3[bnb3.neighbourhood.isna()])
# Out:
# 6872

# %% [markdown]
# # Utilizo el modelo NearestNeighbors para asignar un barrio a aquellos valores nulos en función de las columnas ['latitude', 'longitude']

# %%
bnb_nulos = bnb3[bnb3['neighbourhood'].isnull()]

# Filtrar las filas sin valores nulos en 'barrio'
bnb_no_nulos = bnb3.dropna(subset=['neighbourhood'])

# Definir el número de vecinos cercanos a considerar
num_neighbors = 1

# Inicializar el modelo NearestNeighbors
neighbors_model = NearestNeighbors(n_neighbors=num_neighbors)

# Ajustar el modelo a las coordenadas sin valores nulos en 'barrio'
neighbors_model.fit(bnb_no_nulos[['latitude', 'longitude']])

# Encontrar los vecinos más cercanos para las filas con valores nulos en 'barrio'
distances, indices = neighbors_model.kneighbors(bnb_nulos[['latitude', 'longitude']])

# Asociar los valores nulos en 'barrio' con los barrios correspondientes de los vecinos más cercanos
bnb3.loc[bnb3['neighbourhood'].isnull(), 'neighbourhood'] = bnb_no_nulos.iloc[indices[:, 0]]['neighbourhood'].values

# %%
bnb3 = bnb3.drop("thumbnail_url", axis=1)
bnb3 = bnb3.drop("zipcode", axis=1)

# %%
bnb3['review_scores_rating'] = bnb3['review_scores_rating'].fillna(bnb3.review_scores_rating.mean())

# %% [markdown]
# # Relleno los valores nulos en la columna bathroom con el promedio de baños para el número de huespedes

# %%
average_bedrooms = bnb3.groupby('accommodates')['bedrooms'].transform('mean')

# Llenar los valores nulos en la columna 'bathrooms' con los promedios calculados
bnb3['bedrooms'] = bnb3['bedrooms'].fillna(average_bedrooms)
bnb3['bedrooms'] = bnb3['bedrooms'].round(1)

# %%
bnb3['bedrooms'] = bnb3['bedrooms'].astype(int)

# %%
bnb3['review_scores_rating'] = bnb3['review_scores_rating'].astype(int)

# %%
bnb3 = bnb3.drop("name", axis=1)
bnb3 = bnb3.drop("amenities", axis=1)

# %%
average_bedrooms = bnb3.groupby('accommodates')['beds'].transform('mean')

# Llenar los valores nulos en la columna 'bathrooms' con los promedios calculados
bnb3['beds'] = bnb3['beds'].fillna(average_bedrooms)
bnb3['beds'] = bnb3['beds'].round(1)
bnb3['beds'] = bnb3['beds'].astype(int)

# %% [markdown]
# # Utilizo la columna host_since para categorizar la antiguedad del host en 4 categorías

# %%
# Convertir la columna 'host_since' a tipo datetime
bnb3['host_since'] = pd.to_datetime(bnb3['host_since'])

# 1. Extracción de Año y Mes
bnb3['host_year'] = bnb3['host_since'].dt.year
bnb3['host_month'] = bnb3['host_since'].dt.month

# 2. Calcular la Antigüedad en Años
bnb3['host_age_years'] = (pd.to_datetime('2017-10-04 00:00:00') - bnb3['host_since']).dt.days / 365.25

# 3. Creación de Categorías por Rangos de Tiempo
bins = [0, 1, 2, 5, float('inf')]  # Ajustar los puntos de corte según el rango de fechas
labels = ['nuevo', 'poco_experimentado', 'experimentado', 'muy_experimentado']
bnb3['host_experience'] = pd.cut(bnb3['host_age_years'], bins=bins, labels=labels)

# %%
bnb3.host_experience.value_counts()
# Out:
# experimentado         38556
# poco_experimentado    14540
# muy_experimentado     13497
# nuevo                  7474
# Name: host_experience, dtype: int64

# %%
columns = ['host_year', 'host_month']
bnb3 = bnb3.drop(columns, axis=1)

# %% [markdown]
# # Separo ambos Dataframes en 2

# %%
bnb4 = bnb3[bnb3.log_price.isna()]

# %%
bnb3 =bnb3[bnb3.log_price.notna()]

# %% [markdown]
# # Clusterizo los barrios solo con train

# %%
# Asumiendo que 'log_price' y 'neighbourhood' son columnas relevantes en tu DataFrame
X = bnb3[['log_price', 'neighbourhood']]

# Calcula la media del log_price para cada barrio
neighbourhood_means = X.groupby('neighbourhood')['log_price'].mean().reset_index()

# Crea un DataFrame con las medias del log_price por barrio
neighbourhood_means.columns = ['neighbourhood', 'log_price_mean']

# Normaliza la columna 'log_price_mean'
scaler = StandardScaler()
neighbourhood_means_scaled = scaler.fit_transform(neighbourhood_means[['log_price_mean']])

# Aplica el algoritmo de k-means a las medias normalizadas
kmeans = KMeans(n_clusters=10, random_state=42)
neighbourhood_means['neighbourhood_cluster'] = kmeans.fit_predict(neighbourhood_means_scaled)

# Ordena los clusters según la media del log_price
cluster_order = neighbourhood_means.groupby('neighbourhood_cluster')['log_price_mean'].mean().sort_values().index
neighbourhood_means['neighbourhood_cluster'] = neighbourhood_means['neighbourhood_cluster'].map(
    {cluster: order + 1 for order, cluster in enumerate(cluster_order)}
)

# Crea un diccionario de mapeo de barrios a clusters
neighbourhood_cluster_mapping = dict(zip(neighbourhood_means['neighbourhood'], neighbourhood_means['neighbourhood_cluster']))

# Aplica el mapeo de clusters al DataFrame original
bnb3['neighbourhood_cluster'] = bnb3['neighbourhood'].map(neighbourhood_cluster_mapping)
# Out:
# C:\Users\daarr\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\daarr\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# # Grafica los puntos de los barrios y sus clusters, coloreando por property_type
# plt.figure(figsize=(12, 8))
# sns.scatterplot(x='log_price', y='neighbourhood', hue='neighbourhood_cluster',
#                 style='neighbourhood', data=bnb3, palette='viridis', s=100)
# plt.title('Clusters de Tipos de Propiedad basados en Media de Log_Price')
# plt.xlabel('Log_Price')
# plt.ylabel('Barrio')
# plt.legend(title='Cluster', loc='upper right', bbox_to_anchor=(1.25, 1))
# plt.show();

# %%
bnb3.neighbourhood_cluster.value_counts()
# Out:
# 6     12923
# 8     12404
# 7     11242
# 4     10184
# 5      6441
# 9      3177
# 3      2373
# 2       490
# 1        37
# 10       17
# Name: neighbourhood_cluster, dtype: int64

# %% [markdown]
# # Genero una variable mean_log_price como la media del log_price de los pares property_type - accommodates solo con train

# %%
# Supongamos que 'bnb' es tu DataFrame
# Calcula la media del log_price para cada combinación de property_type y accommodates
grouped_df = bnb3.groupby(['property_type','accommodates'])['log_price'].mean().reset_index()

# Renombra la columna resultante
grouped_df = grouped_df.rename(columns={'log_price': 'mean_log_price'})

# Fusiona los resultados de nuevo en el DataFrame original
bnb3 = pd.merge(bnb3, grouped_df, on=['property_type','accommodates'], how='left')

# %% [markdown]
# # Busco el par property_type - accommodates de cada row en test y le asigno el mean_log_price correspondiente

# %%
# Crea un diccionario de mapeo basado en la combinación de 'property_type' y 'accommodates'
mapping_dict = bnb3.groupby(['property_type', 'accommodates'])['mean_log_price'].mean().to_dict()

# Mapa de valores de 'mean_log_price' al DataFrame a predecir
bnb4['mean_log_price'] = bnb4[['property_type', 'accommodates']].apply(lambda x: mapping_dict.get(tuple(x), np.nan), axis=1)

# Si hay valores nulos después de la asignación, llenarlos con la media global
mean_log_price_global = bnb3['log_price'].mean()
bnb4['mean_log_price'].fillna(mean_log_price_global, inplace=True)

# %% [markdown]
# # Vuelvo a juntar los Dataframes train y test

# %%
bnb3 = pd.concat([bnb3,bnb4])

# %% [markdown]
# # Le asigno el cluster correspondiente a cada neighbourhood y el valor del cluster intermedio en caso de que el barrio no se encuentre en train

# %%
barrio_cluster_mapping = bnb3.groupby('neighbourhood')['neighbourhood_cluster'].apply(lambda x: x.mode().iat[0] if not x.mode().empty else None).to_dict()
barrio_cluster_mapping
# Out:
# {'16th Street Heights': 6.0,
#  'Adams Morgan': 7.0,
#  'Alamo Square': 8.0,
#  'Albany Park': 3.0,
#  'Alhambra': 3.0,
#  'Allerton': 3.0,
#  'Allston-Brighton': 4.0,
#  'Alondra Park': 2.0,
#  'Alphabet City': 7.0,
#  'Altadena': 5.0,
#  'American University Park': 7.0,
#  'Anacostia': 3.0,
#  'Andersonville': 6.0,
#  'Annadale': 6.0,
#  'Arboretum': 3.0,
#  'Arcadia': 5.0,
#  'Archer Heights': 2.0,
#  'Arleta': 4.0,
#  'Armour Square': 3.0,
#  'Arrochar': 6.0,
#  'Artesia': 2.0,
#  'Arts District': 6.0,
#  'Ashburn': 2.0,
#  'Astoria': 5.0,
#  'Atwater Village': 6.0,
#  'Auburn Gresham': 3.0,
#  'Austin': 4.0,
#  'Avondale': 4.0,
#  'Azusa': 3.0,
#  'Back Bay': 8.0,
#  'Back of the Yards': 4.0,
#  'Balboa Terrace': 7.0,
#  'Baldwin Hills': 6.0,
#  'Baldwin Park': 2.0,
#  'Barney Circle': 8.0,
#  'Barry Farm': 3.0,
#  'Bath Beach': 4.0,
#  'Battery Park City': 9.0,
#  'Bay Ridge': 3.0,
#  'Baychester': 3.0,
#  'Bayside': 5.0,
#  'Bayview': 6.0,
#  'Beacon Hill': 8.0,
#  'Bedford Park': 3.0,
#  'Bedford-Stuyvesant': 4.0,
#  'Bel Air/Beverly Crest': 9.0,
#  'Bell': 2.0,
#  'Bellevue': 9.0,
#  'Bellflower': 5.0,
#  'Belmont': 5.0,
#  'Belmont Cragin': 2.0,
#  'Benning': 6.0,
#  'Benning Heights': 2.0,
#  'Benning Ridge': 3.0,
#  'Bensonhurst': 3.0,
#  'Bergen Beach': 4.0,
#  'Berkley': 7.0,
#  'Bernal Heights': 8.0,
#  'Bethesda, MD': 7.0,
#  'Beverly': 5.0,
#  'Beverly Hills': 8.0,
#  'Bloomingdale': 6.0,
#  'Boerum Hill': 7.0,
#  'Borough Park': 3.0,
#  'Boyle Heights': 2.0,
#  'Boystown': 5.0,
#  'Bradbury': 8.0,
#  'Brentwood': 7.0,
#  'Bridgeport': 3.0,
#  'Brighton Beach': 6.0,
#  'Brighton Park': 3.0,
#  'Brightwood': 6.0,
#  'Bronxdale': 2.0,
#  'Bronzeville': 5.0,
#  'Brookland': 6.0,
#  'Brookline': 6.0,
#  'Brooklyn': 5.0,
#  'Brooklyn Heights': 7.0,
#  'Brooklyn Navy Yard': 5.0,
#  'Brownsville': 4.0,
#  'Bucktown': 7.0,
#  'Buena Vista': 7.0,
#  'Burbank': 5.0,
#  'Burleith': 6.0,
#  'Bushwick': 4.0,
#  'Cahuenga Pass': 8.0,
#  'Cambridge': 9.0,
#  'Canarsie': 5.0,
#  'Canoga Park': 4.0,
#  'Capitol Hill': 9.0,
#  'Carroll Gardens': 7.0,
#  'Carson': 5.0,
#  'Carver Langston': 6.0,
#  'Castle Hill ': 6.0,
#  'Castleton Corners': 9.0,
#  'Cathedral Heights': 6.0,
#  'Central Northeast/Mahaning Heights': 6.0,
#  'Cerritos': 3.0,
#  'Charlestown': 8.0,
#  'Chatham': 6.0,
#  'Chatsworth': 5.0,
#  'Chelsea': 8.0,
#  'Chestnut Hill': 4.0,
#  'Chevy Chase': 6.0,
#  'Chevy Chase, MD': nan,
#  'Chillum, MD': 9.0,
#  'Chinatown': 7.0,
#  'City Island': 6.0,
#  'Civic Center': 7.0,
#  'Claremont': 3.0,
#  'Clearing': 3.0,
#  'Cleveland Park': 7.0,
#  'Clifton': 4.0,
#  'Clinton Hill': 6.0,
#  'Co-op City': 6.0,
#  'Cobble Hill': 8.0,
#  'Cole Valley': 8.0,
#  'College Point': 3.0,
#  'Colonial Village': 6.0,
#  'Columbia Heights': 7.0,
#  'Columbia Street Waterfront': 7.0,
#  'Commerce': 4.0,
#  'Compton': 3.0,
#  'Concord': 2.0,
#  'Concourse': 3.0,
#  'Concourse Village': 4.0,
#  'Coney Island': 4.0,
#  'Congress Heights': 4.0,
#  'Coolidge Corner': 9.0,
#  'Corona': 2.0,
#  'Country Club': 5.0,
#  'Covina': 3.0,
#  'Cow Hollow': 9.0,
#  'Crestwood': 7.0,
#  'Crocker Amazon': 6.0,
#  'Crotona': 3.0,
#  'Crown Heights': 5.0,
#  'Culver City': 6.0,
#  'Cypress Park': 4.0,
#  'DUMBO': 8.0,
#  'Daly City': 5.0,
#  'Deanwood': 3.0,
#  'Del Rey': 6.0,
#  'Diamond Heights': 7.0,
#  'Ditmars / Steinway': 4.0,
#  'Dogpatch': 9.0,
#  'Dongan Hills': 4.0,
#  'Dorchester': 4.0,
#  'Douglass': 6.0,
#  'Downey': 3.0,
#  'Downtown': 7.0,
#  'Downtown Brooklyn': 7.0,
#  'Downtown Crossing': 8.0,
#  'Downtown/Penn Quarter': 9.0,
#  'Duarte': 4.0,
#  'Duboce Triangle': 8.0,
#  'Dunning': 3.0,
#  'Dupont Circle': 8.0,
#  'Dupont Park': 8.0,
#  'Dyker Heights': 6.0,
#  'Eagle Rock': 6.0,
#  'East Boston': 6.0,
#  'East Corner': 4.0,
#  'East Elmhurst': 3.0,
#  'East Flatbush': 4.0,
#  'East Harlem': 5.0,
#  'East Hollywood': 4.0,
#  'East Los Angeles': 5.0,
#  'East New York': 4.0,
#  'East San Gabriel': 6.0,
#  'East Village': 8.0,
#  'Eastchester': 5.0,
#  'Eastland Gardens': 2.0,
#  'Echo Park': 5.0,
#  'Eckington': 6.0,
#  'Edenwald': 2.0,
#  'Edgewater': 4.0,
#  'Edgewood': 6.0,
#  'Edison Park': 6.0,
#  'El Monte': 3.0,
#  'El Segundo': 5.0,
#  'El Sereno': 5.0,
#  'Elm Park': 6.0,
#  'Elmhurst': 3.0,
#  'Eltingville': 2.0,
#  'Elysian Valley': 5.0,
#  'Emerson Hill': 10.0,
#  'Encino': 8.0,
#  'Englewood': 1.0,
#  'Excelsior': 5.0,
#  'Fairlawn': 7.0,
#  'Fenway/Kenmore': 7.0,
#  'Financial District': 8.0,
#  "Fisherman's Wharf": 9.0,
#  'Flatbush': 4.0,
#  'Flatiron District': 9.0,
#  'Flatlands': 4.0,
#  'Florence-Graham': 4.0,
#  'Flushing': 4.0,
#  'Foggy Bottom': 7.0,
#  'Fordham': 2.0,
#  'Forest Hill': 8.0,
#  'Forest Hills': 5.0,
#  'Fort Davis': 5.0,
#  'Fort Dupont': 6.0,
#  'Fort Greene': 7.0,
#  'Fort Lincoln': 6.0,
#  'Fort Totten': 6.0,
#  'Fort Wadsworth': 5.0,
#  'Foxhall': 8.0,
#  'Fresh Meadows': 2.0,
#  'Friendship Heights': 7.0,
#  'Galewood': 6.0,
#  'Gallaudet': 8.0,
#  'Gardena': 2.0,
#  'Garfield Heights': 2.0,
#  'Garfield Park': 3.0,
#  'Garfield Ridge': 2.0,
#  'Gateway': 10.0,
#  'Georgetown': 8.0,
#  'Gerritsen Beach': 7.0,
#  'Glassell Park': 6.0,
#  'Glen Park': 8.0,
#  'Glendale': 6.0,
#  'Glendora': 4.0,
#  'Glover Park': 7.0,
#  'Gold Coast': 7.0,
#  'Good Hope': 6.0,
#  'Government Center': nan,
#  'Gowanus': 7.0,
#  'Gramercy Park': 8.0,
#  'Granada Hills North': 4.0,
#  'Grand Crossing': 4.0,
#  'Graniteville': nan,
#  'Grant City': 4.0,
#  'Grasmere': 2.0,
#  'Gravesend': 3.0,
#  'Great Kills': 6.0,
#  'Greenpoint': 6.0,
#  'Greenway': 3.0,
#  'Greenwich Village': 8.0,
#  'Greenwood Heights': 5.0,
#  'Grymes Hill': 5.0,
#  'Haight-Ashbury': 8.0,
#  'Hamilton Heights': 4.0,
#  'Harbor City': 4.0,
#  'Harbor Gateway': 2.0,
#  'Harlem': 6.0,
#  'Harvard Square': 9.0,
#  'Hawaiian Gardens': 4.0,
#  'Hawthorne': 4.0,
#  'Hayes Valley': 9.0,
#  "Hell's Kitchen": 8.0,
#  'Hermon': 4.0,
#  'Hermosa': 3.0,
#  'Hermosa Beach': 9.0,
#  'Highbridge': 3.0,
#  'Highland Park': 5.0,
#  'Hilcrest Heights/Marlow Heights, MD': 3.0,
#  'Hillbrook': 2.0,
#  'Hillcrest': 6.0,
#  'Hollywood': 6.0,
#  'Hollywood Hills': 7.0,
#  'Howard Beach': 4.0,
#  'Hudson Square': 8.0,
#  'Huguenot': 8.0,
#  'Humboldt Park': 4.0,
#  'Huntington Park': 1.0,
#  'Hunts Point': 2.0,
#  'Hyde Park': 4.0,
#  'Ingleside': 6.0,
#  'Inglewood': 3.0,
#  'Inner Sunset': 7.0,
#  'Inwood': 4.0,
#  'Irving Park': 4.0,
#  'Irwindale': 2.0,
#  'Ivy City': 4.0,
#  'Jackson Heights': 4.0,
#  'Jamaica': 4.0,
#  'Jamaica Plain': 6.0,
#  'Japantown': 7.0,
#  'Jefferson Park': 4.0,
#  'Judiciary Square': 9.0,
#  'Kalorama': 7.0,
#  'Kensington': 4.0,
#  'Kent': 7.0,
#  'Kenwood': 4.0,
#  'Kew Garden Hills': 4.0,
#  'Kingman Park': 7.0,
#  'Kingsbridge': 3.0,
#  'Kingsbridge Heights': 4.0,
#  'Kips Bay': 8.0,
#  'La Canada Flintridge': 6.0,
#  'La Crescenta-Montrose': 5.0,
#  'La Habra': 8.0,
#  'La Mirada': 4.0,
#  'La Puente': 4.0,
#  'Lake Balboa': 4.0,
#  'Lakeshore': 6.0,
#  'Lakeview': 7.0,
#  'Lakewood': 4.0,
#  'Lamond Riggs': 6.0,
#  'Langdon': 6.0,
#  'Laurel Canyon': 9.0,
#  'Lawndale': 4.0,
#  'LeDroit Park': 7.0,
#  'Leather District': 9.0,
#  'Lefferts Garden': 4.0,
#  'Lighthouse HIll': 8.0,
#  'Lincoln Heights': 4.0,
#  'Lincoln Park': 7.0,
#  'Lincoln Square': 5.0,
#  'Lindenwood': 6.0,
#  'Little Italy': 7.0,
#  'Little Italy/UIC': 4.0,
#  'Little Village': 2.0,
#  'Logan Circle': 8.0,
#  'Logan Square': 5.0,
#  'Lomita': 5.0,
#  'Long Beach': 5.0,
#  'Long Island City': 6.0,
#  'Longwood': 3.0,
#  'Loop': 7.0,
#  'Los Feliz': 6.0,
#  'Lower East Side': 7.0,
#  'Lower Haight': 8.0,
#  'Lynwood': 3.0,
#  'Magnificent Mile': 8.0,
#  'Malibu': 9.0,
#  'Manhattan': 7.0,
#  'Manhattan Beach': 8.0,
#  'Manor Park': 5.0,
#  'Mar Vista': 6.0,
#  'Marble Hill': 3.0,
#  'Marina': 9.0,
#  'Marina Del Rey': 8.0,
#  'Marine Park': 3.0,
#  'Mariners Harbor': 6.0,
#  'Marshall Heights': 5.0,
#  'Maspeth': 4.0,
#  'Massachusetts Heights': 5.0,
#  'Mattapan': 3.0,
#  'McKinley Park': 3.0,
#  'Meatpacking District': 9.0,
#  'Meiers Corners': 3.0,
#  'Melrose': 4.0,
#  'Michigan Park': 5.0,
#  'Mid-City': 4.0,
#  'Mid-Wilshire': 6.0,
#  'Middle Village': 5.0,
#  'Midland Beach': 4.0,
#  'Midtown': 9.0,
#  'Midtown East': 8.0,
#  'Midwood': 4.0,
#  'Mill Basin': 10.0,
#  'Mission Bay': 8.0,
#  'Mission District': 8.0,
#  'Mission Hill': 6.0,
#  'Mission Hills': 7.0,
#  'Mission Terrace': 7.0,
#  'Monrovia': 4.0,
#  'Montclare': 4.0,
#  'Montebello': 5.0,
#  'Montecito Heights': 6.0,
#  'Monterey Hills': 4.0,
#  'Monterey Park': 4.0,
#  'Morgan Park': 2.0,
#  'Morningside Heights': 5.0,
#  'Morris Heights': 3.0,
#  'Morris Park': 1.0,
#  'Morrisania': 6.0,
#  'Mott Haven': 4.0,
#  'Mount Eden': 2.0,
#  'Mount Pleasant': 7.0,
#  'Mount Vernon Square': 8.0,
#  'Mount Washington': 5.0,
#  'Mt Rainier/Brentwood, MD': 8.0,
#  'Mt. Pleasant': 5.0,
#  'Mt. Vernon Square': 9.0,
#  'Murray Hill': 8.0,
#  'Navy Yard': 9.0,
#  'Naylor Gardens': 6.0,
#  'Near North Side': 7.0,
#  'Near Northeast': 3.0,
#  'Near Northeast/H Street Corridor': 8.0,
#  'Near West Side': 5.0,
#  'New Brighton': 5.0,
#  'New Dorp Beach': nan,
#  'New Springville': 5.0,
#  'Newton': 5.0,
#  'Nob Hill': 8.0,
#  'Noe Valley': 8.0,
#  'Noho': 9.0,
#  'Nolita': 8.0,
#  'North Beach': 8.0,
#  'North Center': 7.0,
#  'North Cleveland Park': 6.0,
#  'North End': 8.0,
#  'North Hills East': 6.0,
#  'North Hills West': 5.0,
#  'North Hollywood': 4.0,
#  'North Lawndale': 2.0,
#  'North Michigan Park': 4.0,
#  'North Park': 2.0,
#  'Northridge': 5.0,
#  'Norwalk': 2.0,
#  'Norwood': 3.0,
#  'Norwood Park': 3.0,
#  "O'Hare": 5.0,
#  'Oakland': 4.0,
#  'Oakwood': 5.0,
#  'Observatory Circle': nan,
#  'Oceanview': 6.0,
#  "Old Soldiers' Home": 3.0,
#  'Old Town': 8.0,
#  'Outer Sunset': 7.0,
#  'Ozone Park': 3.0,
#  'Pacific Heights': 9.0,
#  'Pacific Palisades': 9.0,
#  'Pacoima': 4.0,
#  'Palisades': 8.0,
#  'Palms': 4.0,
#  'Palos Verdes': 10.0,
#  'Panorama City': 3.0,
#  'Paramount': 3.0,
#  'Park Slope': 7.0,
#  'Park Versailles': 2.0,
#  'Park View': 7.0,
#  'Parkchester': 2.0,
#  'Parkside': 7.0,
#  'Pasadena': 6.0,
#  'Pelham Bay': 2.0,
#  'Petworth': 6.0,
#  'Pico Rivera': 3.0,
#  'Pilsen': 3.0,
#  'Pleasant Hill': 6.0,
#  'Pleasant Plains': 6.0,
#  'Port Morris': 4.0,
#  'Port Richmond': 5.0,
#  'Portage Park': 4.0,
#  'Porter Ranch': 5.0,
#  'Portola': 6.0,
#  'Potrero Hill': 8.0,
#  'Presidio': 9.0,
#  'Presidio Heights': 9.0,
#  'Printers Row': 8.0,
#  'Prospect Heights': 6.0,
#  'Pullman': 4.0,
#  'Queens': 3.0,
#  'Rancho Palos Verdes': 9.0,
#  'Randall Manor': 5.0,
#  'Randle Highlands': 8.0,
#  'Red Hook': 6.0,
#  'Redondo Beach': 6.0,
#  'Rego Park': 4.0,
#  'Reseda': 4.0,
#  'Richmond District': 8.0,
#  'Richmond Hill': 3.0,
#  'Ridgewood': 3.0,
#  'River North': 8.0,
#  'River Terrace': 4.0,
#  'River West': 8.0,
#  'Riverdale': 4.0,
#  'Rogers Park': 4.0,
#  'Rolling Hills': 5.0,
#  'Rolling Hills Estates': 8.0,
#  'Roosevelt Island': 4.0,
#  'Roscoe Village': 7.0,
#  'Rosebank': 3.0,
#  'Roseland': 4.0,
#  'Rosemead': 5.0,
#  'Roslindale': 4.0,
#  'Rossville': 9.0,
#  'Roxbury': 5.0,
#  'Russian Hill': 9.0,
#  'San Gabriel': 3.0,
#  'San Marino': 5.0,
#  'San Pedro': 7.0,
#  'Santa Fe Springs': 2.0,
#  'Santa Monica': 7.0,
#  'Sea Cliff': 10.0,
#  'Sea Gate': 6.0,
#  'Shaw': 7.0,
#  'Sheepshead Bay': 4.0,
#  'Shepherd Park': 7.0,
#  'Sherman Oaks': 7.0,
#  'Shipley Terrace': 6.0,
#  'Sierra Madre': 4.0,
#  'Signal Hill': 6.0,
#  'Silver Lake': 6.0,
#  'Silver Spring, MD': 8.0,
#  'Skid Row': 7.0,
#  'Skyland': 10.0,
#  'SoMa': 8.0,
#  'Soho': 8.0,
#  'Somerville': 2.0,
#  'Soundview': 3.0,
#  'South Beach': 8.0,
#  'South Boston': 8.0,
#  'South Chicago': 1.0,
#  'South El Monte': 3.0,
#  'South End': 8.0,
#  'South Gate': 3.0,
#  'South LA': 3.0,
#  'South Loop/Printers Row': 8.0,
#  'South Ozone Park': 4.0,
#  'South Pasadena': 7.0,
#  'South Robertson': 5.0,
#  'South San Gabriel': 3.0,
#  'South Shore': 2.0,
#  'South Street Seaport': 7.0,
#  'South Whittier': 2.0,
#  'Southwest Waterfront': 7.0,
#  'Spring Valley': 6.0,
#  'Spuyten Duyvil': 6.0,
#  'St. Elizabeths': 4.0,
#  'St. George': 5.0,
#  'Stapleton': 5.0,
#  'Streeterville': 8.0,
#  'Stronghold': 7.0,
#  'Studio City': 7.0,
#  'Suitland-Silver Hill, MD': nan,
#  'Sun Valley': 5.0,
#  'Sunland/Tujunga': 4.0,
#  'Sunnyside': 5.0,
#  'Sunset Park': 3.0,
#  'Sylmar': 5.0,
#  'Takoma': 4.0,
#  'Takoma Park, MD': 8.0,
#  'Tarzana': 6.0,
#  'Telegraph Hill': 9.0,
#  'Temple City': 4.0,
#  'Tenderloin': 7.0,
#  'The Bronx': 4.0,
#  'The Castro': 8.0,
#  'The Rockaways': 5.0,
#  'Theater District': 8.0,
#  'Throgs Neck': 6.0,
#  'Times Square/Theatre District': 8.0,
#  'Todt Hill': 9.0,
#  'Toluca Lake': 6.0,
#  'Tompkinsville': 4.0,
#  'Topanga': 8.0,
#  'Torrance': 5.0,
#  'Tottenville': 8.0,
#  'Tremont': 4.0,
#  'Tribeca': 9.0,
#  'Trinidad': 6.0,
#  'Truxton Circle': 7.0,
#  'Twin Peaks': 8.0,
#  'Twining': 1.0,
#  'U Street Corridor': 8.0,
#  'Ukrainian Village': 6.0,
#  'Union Square': 9.0,
#  'University Heights': 2.0,
#  'Upper East Side': 7.0,
#  'Upper West Side': 7.0,
#  'Uptown': 4.0,
#  'Utopia': 2.0,
#  'Valley Glen': 3.0,
#  'Valley Village': 5.0,
#  'Van Nest': 6.0,
#  'Van Nuys': 4.0,
#  'Venice': 8.0,
#  'Vernon': 7.0,
#  'Vinegar Hill': 6.0,
#  'Visitacion Valley': 5.0,
#  'Wakefield': 4.0,
#  'Washington Heights': 4.0,
#  'Washington Highlands': 6.0,
#  'Washington Park': 2.0,
#  'Watertown': 8.0,
#  'Watts': 4.0,
#  'Wesley Heights': 7.0,
#  'West Adams': 3.0,
#  'West Athens': 9.0,
#  'West Brighton': 4.0,
#  'West Covina': 3.0,
#  'West Elsdon': 1.0,
#  'West End': 8.0,
#  'West Farms': 3.0,
#  'West Hills': 4.0,
#  'West Hollywood': 7.0,
#  'West Lawn': 2.0,
#  'West Loop/Greektown': 7.0,
#  'West Los Angeles': 6.0,
#  'West Portal': 6.0,
#  'West Puente Valley': 2.0,
#  'West Ridge': 2.0,
#  'West Roxbury': 5.0,
#  'West Town': 2.0,
#  'West Town/Noble Square': 6.0,
#  'West Village': 9.0,
#  'Westchester Village': 2.0,
#  'Westchester/Playa Del Rey': 6.0,
#  'Westerleigh': 7.0,
#  'Western Addition/NOPA': 8.0,
#  'Westlake': 4.0,
#  'Westmont': 3.0,
#  'Westside': 6.0,
#  'Westwood': 7.0,
#  'Whitestone': 4.0,
#  'Whittier': 4.0,
#  'Wicker Park': 6.0,
#  'Williamsbridge': 4.0,
#  'Williamsburg': 6.0,
#  'Willowbrook': 5.0,
#  'Wilmington': 10.0,
#  'Windsor Terrace': 6.0,
#  'Winnetka': 4.0,
#  'Winthrop': 4.0,
#  'Woodhaven': 2.0,
#  'Woodland': 7.0,
#  'Woodland Hills/Warner Center': 6.0,
#  'Woodlawn': 4.0,
#  'Woodley Park': 8.0,
#  'Woodridge': 5.0,
#  'Woodside': 4.0,
#  'Wrigleyville': 7.0}

# %%
# Llenar los valores nulos usando el diccionario
bnb3['neighbourhood_cluster'] = bnb3['neighbourhood'].map(barrio_cluster_mapping).fillna(bnb3['neighbourhood_cluster'])

# %%
bnb3['neighbourhood_cluster'] = bnb3['neighbourhood_cluster'].fillna(5)

# %%
bnb3 = bnb3.drop("latitude", axis=1)
bnb3 = bnb3.drop("longitude", axis=1)

# %%
bnb3['host_experience'] = bnb3['host_experience'].fillna("nuevo")

# %%
columns = ["host_age_years","host_since"]
bnb3 = bnb3.drop(columns, axis=1)

# %%
bnb4 = bnb3[bnb3.log_price.isna()]

# %%
bnb4 = bnb4.drop("log_price", axis=1)

# %%
bnb4.info(memory_usage = "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14823 entries, 0 to 14822
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     14823 non-null  int64
#  1   property_type          14823 non-null  object
#  2   room_type              14823 non-null  object
#  3   accommodates           14823 non-null  int64
#  4   bathrooms              14823 non-null  float64
#  5   bed_type               14823 non-null  object
#  6   cancellation_policy    14823 non-null  object
#  7   cleaning_fee           14823 non-null  int32
#  8   city                   14823 non-null  object
#  9   description            14823 non-null  object
#  10  host_response_rate     14823 non-null  int32
#  11  instant_bookable       14823 non-null  int64
#  12  neighbourhood          14823 non-null  object
#  13  number_of_reviews      14823 non-null  int64
#  14  review_scores_rating   14823 non-null  int32
#  15  bedrooms               14823 non-null  int32
#  16  beds                   14823 non-null  int32
#  17  host_experience        14823 non-null  category
#  18  neighbourhood_cluster  14823 non-null  float64
#  19  mean_log_price         14823 non-null  float64
# dtypes: category(1), float64(3), int32(5), int64(4), object(7)
# memory usage: 20.1 MB

# %% [markdown]
# # Me quedo con las columnas de mayor interés

# %%
bnb4 = bnb4[['room_type', 'cleaning_fee',
           'cancellation_policy','city','host_experience','beds',       
           'accommodates','bathrooms', 'bedrooms', 'property_type','mean_log_price','neighbourhood_cluster','neighbourhood']]

# %%
bnb4.to_csv("../data/test_clean2.csv", index=False)

# %%
bnb3 = bnb3[bnb3.log_price.notna()]

# %%
bnb3 = bnb3[bnb3.log_price != 0]

# %%
bnb3 = bnb3[['log_price', 'room_type', 'cleaning_fee',
           'cancellation_policy','city','host_experience','beds',       
           'accommodates','bathrooms', 'bedrooms', 'property_type','mean_log_price','neighbourhood_cluster','neighbourhood']]

# %%
bnb3.to_csv("../data/train_clean4.csv", index=False)
